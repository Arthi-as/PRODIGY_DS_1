# %% [markdown]
# ### **Importing necessary libraries**

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_excel("D:/ARTHI/prodigy info tech/API_SP.POP.TOTL_DS2_en_csv_v2_40826.xlsx")

# %%
df.head()
# Out:
#                   Country Name Country Code     Indicator Name  \
# 0                        Aruba          ABW  Population, total
# 1  Africa Eastern and Southern          AFE  Population, total
# 2                  Afghanistan          AFG  Population, total
# 3   Africa Western and Central          AFW  Population, total
# 4   Africa Western and Central          AFW  Population, total
#
#    Indicator Code       1960       1961       1962       1963       1964  \
# 0  SP.POP.TOTL.MA      54922      55578      56320      57002      57619
# 1  SP.POP.TOTL.MA  130075728  133534923  137171659  140945536  144904094
# 2  SP.POP.TOTL.MA    9035043    9214083    9404406    9604487    9814318
# 3  SP.POP.TOTL.MA   97630925   99706674  101854756  104089175  106388440
# 4  SP.POP.TOTL.FE   91540853   93931683   96428599   99038509  101729760
#
#         1965  ...       2015       2016       2017       2018       2019  \
# ...

# %%
df.tail()
# Out:
#      Country Name Country Code     Indicator Name Indicator Code      1960  \
# 264        Kosovo          XKX  Population, total    SP.POP.TOTL    984846
# 265   Yemen, Rep.          YEM  Population, total    SP.POP.TOTL   5532301
# 266  South Africa          ZAF  Population, total    SP.POP.TOTL  16440172
# 267        Zambia          ZMB  Population, total    SP.POP.TOTL   3153729
# 268      Zimbabwe          ZWE  Population, total    SP.POP.TOTL   3809389
#
#          1961      1962      1963      1964      1965  ...      2015  \
# 264   1011421   1036950   1062737   1090270   1120168  ...   1788274
# 265   5655232   5782221   5911135   6048006   6195593  ...  31159379
# 266  16908035  17418522  17954564  18511361  19089380  ...  56723537
# 267   3254086   3358099   3465907   3577017   3692086  ...  16399089
# 268   3930401   4055959   4185877   4320006   4458462  ...  14399013
#
#          2016      2017      2018      2019      2020      2021      2022  \
# ...

# %%
df.columns
# Out:
# Index([  'Country Name',   'Country Code', 'Indicator Name', 'Indicator Code',
#                    1960,             1961,             1962,             1963,
#                    1964,             1965,             1966,             1967,
#                    1968,             1969,             1970,             1971,
#                    1972,             1973,             1974,             1975,
#                    1976,             1977,             1978,             1979,
#                    1980,             1981,             1982,             1983,
#                    1984,             1985,             1986,             1987,
#                    1988,             1989,             1990,             1991,
#                    1992,             1993,             1994,             1995,
#                    1996,             1997,             1998,             1999,
#                    2000,             2001,             2002,             2003,
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 269 entries, 0 to 268
# Data columns (total 69 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Country Name    269 non-null    object
#  1   Country Code    269 non-null    object
#  2   Indicator Name  269 non-null    object
#  3   Indicator Code  269 non-null    object
#  4   1960            269 non-null    int64
#  5   1961            269 non-null    int64
#  6   1962            269 non-null    int64
#  7   1963            269 non-null    int64
#  8   1964            269 non-null    int64
#  9   1965            269 non-null    int64
#  10  1966            269 non-null    int64
#  11  1967            269 non-null    int64
#  12  1968            269 non-null    int64
#  13  1969            269 non-null    int64
#  14  1970            269 non-null    int64
#  15  1971            269 non-null    int64
#  16  1972            269 non-null    int64
# ...

# %%
df.describe()
# Out:
#                1960          1961          1962          1963          1964  \
# count  2.690000e+02  2.690000e+02  2.690000e+02  2.690000e+02  2.690000e+02
# mean   1.150300e+08  1.166272e+08  1.187710e+08  1.214157e+08  1.240845e+08
# std    3.587456e+08  3.631875e+08  3.697584e+08  3.782765e+08  3.868414e+08
# min    2.715000e+03  2.970000e+03  3.264000e+03  3.584000e+03  3.922000e+03
# 25%    5.304850e+05  5.398540e+05  5.499410e+05  5.608270e+05  5.725770e+05
# 50%    3.702323e+06  3.810151e+06  3.956939e+06  4.112061e+06  4.252876e+06
# 75%    2.689648e+07  2.765033e+07  2.848104e+07  2.934232e+07  3.023214e+07
# max    3.021513e+09  3.062768e+09  3.117372e+09  3.184063e+09  3.251253e+09
#
#                1965          1966          1967          1968          1969  \
# count  2.690000e+02  2.690000e+02  2.690000e+02  2.690000e+02  2.690000e+02
# mean   1.267843e+08  1.296016e+08  1.324269e+08  1.353255e+08  1.383208e+08
# ...

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.isnull().sum()
# Out:
# Country Name      0
# Country Code      0
# Indicator Name    0
# Indicator Code    0
# 1960              0
#                  ..
# 2020              0
# 2021              0
# 2022              0
# 2023              0
# 2024              0
# Length: 69, dtype: int64

# %%
#print(df['Country Name'].unique())
print("\n Total number of unique countries:",df["Country Name"].unique())
# Out:
#  Total number of unique countries: ['Aruba' 'Africa Eastern and Southern' 'Afghanistan'
#  'Africa Western and Central' 'Angola' 'Albania' 'Andorra' 'Arab World'
#  'United Arab Emirates' 'Argentina' 'Armenia' 'American Samoa'
#  'Antigua and Barbuda' 'Australia' 'Austria' 'Azerbaijan' 'Burundi'
#  'Belgium' 'Benin' 'Burkina Faso' 'Bangladesh' 'Bulgaria' 'Bahrain'
#  'Bahamas, The' 'Bosnia and Herzegovina' 'Belarus' 'Belize' 'Bermuda'
#  'Bolivia' 'Brazil' 'Barbados' 'Brunei Darussalam' 'Bhutan' 'Botswana'
#  'Central African Republic' 'Canada' 'Central Europe and the Baltics'
#  'Switzerland' 'Channel Islands' 'Chile' 'China' "Cote d'Ivoire"
#  'Cameroon' 'Congo, Dem. Rep.' 'Congo, Rep.' 'Colombia' 'Comoros'
#  'Cabo Verde' 'Costa Rica' 'Caribbean small states' 'Cuba' 'Curacao'
#  'Cayman Islands' 'Cyprus' 'Czechia' 'Germany' 'Djibouti' 'Dominica'
#  'Denmark' 'Dominican Republic' 'Algeria'
#  'East Asia & Pacific (excluding high income)'
# ...

# %%
print("\n Total number of unique country code:",df["Country Code"].unique())
# Out:
#  Total number of unique country code: ['ABW' 'AFE' 'AFG' 'AFW' 'AGO' 'ALB' 'AND' 'ARB' 'ARE' 'ARG' 'ARM' 'ASM'
#  'ATG' 'AUS' 'AUT' 'AZE' 'BDI' 'BEL' 'BEN' 'BFA' 'BGD' 'BGR' 'BHR' 'BHS'
#  'BIH' 'BLR' 'BLZ' 'BMU' 'BOL' 'BRA' 'BRB' 'BRN' 'BTN' 'BWA' 'CAF' 'CAN'
#  'CEB' 'CHE' 'CHI' 'CHL' 'CHN' 'CIV' 'CMR' 'COD' 'COG' 'COL' 'COM' 'CPV'
#  'CRI' 'CSS' 'CUB' 'CUW' 'CYM' 'CYP' 'CZE' 'DEU' 'DJI' 'DMA' 'DNK' 'DOM'
#  'DZA' 'EAP' 'EAR' 'EAS' 'ECA' 'ECS' 'ECU' 'EGY' 'EMU' 'ERI' 'ESP' 'EST'
#  'ETH' 'EUU' 'FCS' 'FIN' 'FJI' 'FRA' 'FRO' 'FSM' 'GAB' 'GBR' 'GEO' 'GHA'
#  'GIB' 'GIN' 'GMB' 'GNB' 'GNQ' 'GRC' 'GRD' 'GRL' 'GTM' 'GUM' 'GUY' 'HIC'
#  'HKG' 'HND' 'HPC' 'HRV' 'HTI' 'HUN' 'IBD' 'IBT' 'IDA' 'IDB' 'IDN' 'IDX'
#  'IMN' 'IND' 'IRL' 'IRN' 'IRQ' 'ISL' 'ISR' 'ITA' 'JAM' 'JOR' 'JPN' 'KAZ'
#  'KEN' 'KGZ' 'KHM' 'KIR' 'KNA' 'KOR' 'KWT' 'LAC' 'LAO' 'LBN' 'LBR' 'LBY'
#  'LCA' 'LCN' 'LDC' 'LIC' 'LIE' 'LKA' 'LMC' 'LMY' 'LSO' 'LTE' 'LTU' 'LUX'
# ...

# %%
df.columns
# Out:
# Index([  'Country Name',   'Country Code', 'Indicator Name', 'Indicator Code',
#                    1960,             1961,             1962,             1963,
#                    1964,             1965,             1966,             1967,
#                    1968,             1969,             1970,             1971,
#                    1972,             1973,             1974,             1975,
#                    1976,             1977,             1978,             1979,
#                    1980,             1981,             1982,             1983,
#                    1984,             1985,             1986,             1987,
#                    1988,             1989,             1990,             1991,
#                    1992,             1993,             1994,             1995,
#                    1996,             1997,             1998,             1999,
#                    2000,             2001,             2002,             2003,
# ...

# %%
df.drop(['Indicator Name'],axis=1,inplace=True)

# %% [markdown]
# #### Extraction of top 10 countries with respect to total population

# %%
total_population_data = df[df['Indicator Code'] == 'SP.POP.TOTL']

# %%
total_population_sorted=total_population_data.sort_values(by=2022,ascending=False)
total_top_10_countries=total_population_sorted.head(10)
print("Top 10 countries of total population\n")
print(total_top_10_countries[['Country Code']])
# Out:
# Top 10 countries of total population
#
#     Country Code
# 262          WLD
# 107          IBT
# 144          LMY
# 160          MIC
# 106          IBD
# 65           EAR
# 143          LMC
# 252          UMC
# 66           EAS
# 146          LTE

# %%
# Create the bar plot
plt.figure(figsize=(15, 6))
plt.subplot(2, 2, 1)
sns.barplot(x=2022, y="Country Code", data=total_top_10_countries, palette="coolwarm")
plt.title("Top Ten Countries of Total Population (2022)", fontsize=10)
plt.xlabel("Total Population", fontsize=10)
plt.ylabel("Country", fontsize=10)
plt.show()

# Create the bar plot
plt.figure(figsize=(15, 6))
plt.subplot(2, 2, 2)
sns.barplot(x=2016, y="Country Code", data=total_top_10_countries, palette="coolwarm")
plt.title("Top Ten Countries of Total Population (2016)", fontsize=10)
plt.xlabel("Total Population", fontsize=10)
plt.ylabel("Country", fontsize=10)
plt.show()
# Out:
# C:\Users\ARTHI\AppData\Local\Temp\ipykernel_44436\3893882444.py:4: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=2022, y="Country Code", data=total_top_10_countries, palette="coolwarm")
# C:\Users\ARTHI\AppData\Local\Temp\ipykernel_44436\3893882444.py:13: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=2016, y="Country Code", data=total_top_10_countries, palette="coolwarm")

# %%
total_population_sorted=total_population_data.sort_values(by=2022,ascending=True)
total_bottom_10_countries=total_population_sorted.head(10)
print("Bottom 10 countries of total population\n")
print(total_bottom_10_countries[['Country Code']])
# Out:
# Bottom 10 countries of total population
#
#     Country Code
# 248          TUV
# 183          NRU
# 192          PLW
# 151          MAF
# 215          SMR
# 88           GIB
# 258          VGB
# 153          MCO
# 141          LIE
# 159          MHL

# %%
# Create the bar plot
plt.figure(figsize=(15, 6))
plt.subplot(2, 2, 1)
sns.barplot(x=2022, y="Country Code", data=total_bottom_10_countries, palette="coolwarm")
plt.title("Bottom Ten Countries of Total Population (2022)", fontsize=10)
plt.xlabel("Total Population", fontsize=10)
plt.ylabel("Country", fontsize=10)
plt.show()

# Create the bar plot
plt.figure(figsize=(15, 6))
plt.subplot(2, 2, 2)
sns.barplot(x=2016, y="Country Code", data=total_bottom_10_countries, palette="coolwarm")
plt.title("Bottom Ten Countries of Total Population (2016)", fontsize=10)
plt.xlabel("Total Population", fontsize=10)
plt.ylabel("Country", fontsize=10)
plt.show()
# Out:
# C:\Users\ARTHI\AppData\Local\Temp\ipykernel_44436\4235676061.py:4: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=2022, y="Country Code", data=total_bottom_10_countries, palette="coolwarm")
# C:\Users\ARTHI\AppData\Local\Temp\ipykernel_44436\4235676061.py:13: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=2016, y="Country Code", data=total_bottom_10_countries, palette="coolwarm")

# %% [markdown]
# #### **Extraction of top 10 countries with highest male population**

# %%
male_population_data=df[df['Indicator Code']=='SP.POP.TOTL.MA']
# Sort data based on the male population for 2022
male_population_sorted = male_population_data.sort_values(
    by=2022,
    ascending=False
)

# Get the top ten countries with the highest male population for 2022
male_top_ten_countries = male_population_sorted.head(10)

print("Top ten countries of male population")
print(male_top_ten_countries[['Country Code']])
# Out:
# Top ten countries of male population
#     Country Code
# 1            AFE
# 3            AFW
# 8            ARB
# 10           ARG
# 119          ISR
# 2            AFG
# 36           CAN
# 5            AGO
# 46           COD
# 14           AUS

# %%
female_population_data=df[df['Indicator Code']==('SP.POP.TOTL.FE')]
# Sort data based on the female population for 2022
female_population_sorted = female_population_data.sort_values(
    by=2022,
    ascending=False
)

# Get the top ten countries with the highest female population for 2022
female_top_ten_countries = female_population_sorted.head(10)

print("Top ten countries of female population")
print(female_top_ten_countries[['Country Code']])
# Out:
# Top ten countries of female population
#    Country Code
# 42          CHN
# 4           AFW
# 79          FIN
# 30          BRA
# 21          BGD
# 45          COD
# 38          CEB
# 48          COL
# 37          CAN
# 43          CIV

# %% [markdown]
# #### **Top 10 countries with highest male and female population in 2022**

# %%
# Create the bar plot
plt.figure(figsize=(15, 6))
plt.subplot(2, 2, 1)
sns.barplot(x=2022, y="Country Code", data=male_top_ten_countries, palette="viridis")
plt.title("Top Ten Countries of male Population (2022)", fontsize=10)
plt.xlabel("Total Population", fontsize=10)
plt.ylabel("Country", fontsize=10)
plt.show()

# Create the bar plot
plt.figure(figsize=(15, 6))
plt.subplot(2, 2, 2)
sns.barplot(x=2016, y="Country Code", data=female_top_ten_countries, palette="viridis")
plt.title("Top Ten Countries of Female Population (2016)", fontsize=10)
plt.xlabel("Total Population", fontsize=10)
plt.ylabel("Country", fontsize=10)
plt.show()
# Out:
# C:\Users\ARTHI\AppData\Local\Temp\ipykernel_44436\3184752744.py:4: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=2022, y="Country Code", data=male_top_ten_countries, palette="viridis")
# C:\Users\ARTHI\AppData\Local\Temp\ipykernel_44436\3184752744.py:13: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=2016, y="Country Code", data=female_top_ten_countries, palette="viridis")

# %% [markdown]
# ### **Stacked bar plot**

# %% [markdown]
# #### Top 10 countries with male and female population

# %%
merge_data=pd.merge(male_population_data,female_population_data,on='Country Code',suffixes=("_male","_female"))

# %%
merge_data['Total population']=merge_data['2022_male']=merge_data["2022_female"]

# %%
merge_data.head()
# Out:
#             Country Name_male Country Code Indicator Code_male  1960_male  \
# 0  Africa Western and Central          AFW      SP.POP.TOTL.MA   97630925
# 1                      Canada          CAN      SP.POP.TOTL.MA   17909356
# 2            Congo, Dem. Rep.          COD      SP.POP.TOTL.MA    3673666
# 3                     Finland          FIN      SP.POP.TOTL.MA    4429634
# 4                      Israel          ISR      SP.POP.TOTL.MA    7022052
#
#    1961_male  1962_male  1963_male  1964_male  1965_male  1966_male  ...  \
# 0   99706674  101854756  104089175  106388440  108772632  111246953  ...
# 1   18271000   18614000   18964000   19325000   19678000   20048000  ...
# 2    3810151    3956939    4112061    4273952    4442377    4617519  ...
# 3    4461005    4491443    4523309    4548543    4563732    4580869  ...
# 4    7194553    7413875    7667928    7929566    8202140    8485104  ...
#
#    2016_female  2017_female  2018_female  2019_female  2020_female  \
# ...

# %%
sorted_data=merge_data.sort_values(by="Total population",ascending=False)

# %% [markdown]
# #### **select the top 10 countries with the highest total population**

# %%
top_10_countries=sorted_data.head(10)

# %%
plt.figure(figsize=(12,6))
sns.barplot(x="Country Code",y="2022_female",data=top_10_countries,color='red',label='Female Population')
sns.barplot(x='Country Code',y='2022_male',data=top_10_countries,bottom=top_10_countries['2022_female'],color='green',label='male population')
plt.xlabel("Country")
plt.ylabel("population")
plt.legend()
plt.xticks(rotation=5,ha='right')
plt.show()
